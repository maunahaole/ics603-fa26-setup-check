# %% [markdown]
# # Notebook workflow check
#
# This notebook verifies that VS Code, the project environment, Jupyter, and Git
# work together.

# %%
from pathlib import Path
import sys

kernel_path = Path(sys.executable)
assert ".venv" in kernel_path.parts
print("Kernel check passed: this notebook is using the project's .venv.")
# Out:
# Kernel check passed: this notebook is using the project's .venv.

# %%
message = "updated value"

# %%
print(message)
# Out:
# updated value
